# %% [markdown]
# ## Intro
#
# For the following analysis we will use the used cars dataset
# [Link](https://www.kaggle.com/orgesleka/used-cars-database/data)
#
# * The dataset is randomly sampled and contains 50,000 observations
#
# The goal of this notebook is to clean and analyze the dataset

# %%
#Import libraries
import numpy as np
import pandas as pd

# %%
#read csv
autos = pd.read_csv("autos.csv",encoding="Latin-1")

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %% [markdown]
# ## Clean Columns
#
# After inspecting the dataset in the above cells here are some initial observations:
# * The columns "vehicleType","gearbox","model","fuelType","notRepairedDamage" contain null values but those are less than ~20% of the total column.
# * From the 20 columns, 15 are of the object(string) type and 5 are int type.
# * Column names use camelcase instead of snakecase(undercores between words)

# %% [markdown]
# In the following cell we will convert the column names to snakecase and reword some of the names to make them more descriptive

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.columns.copy()
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.columns = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'ab_test',
       'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
       'odometer', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'ad_created', 'num_photos', 'postal_code',
       'last_seen']
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price  ab_test vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %%
autos.describe(include="all")
# Out:
#                date_crawled         name  seller offer_type  price ab_test  \
# count                 50000        50000   50000      50000  50000   50000
# unique                48213        38754       2          2   2357       2
# top     2016-03-23 18:39:34  Ford_Fiesta  privat    Angebot     $0    test
# freq                      3           78   49999      49999   1421   25756
# mean                    NaN          NaN     NaN        NaN    NaN     NaN
# std                     NaN          NaN     NaN        NaN    NaN     NaN
# min                     NaN          NaN     NaN        NaN    NaN     NaN
# 25%                     NaN          NaN     NaN        NaN    NaN     NaN
# 50%                     NaN          NaN     NaN        NaN    NaN     NaN
# 75%                     NaN          NaN     NaN        NaN    NaN     NaN
# max                     NaN          NaN     NaN        NaN    NaN     NaN
#
# ...

# %% [markdown]
# ## Exploring other columns
#
# Inspecting the columns above we notice a few things:
# * The columns "seller","offer_type","ab_test","gearbox""unrepaired_damage" contain only two unique values.
#     * Of those the column "ab_test" could probably be dropped as it does not contain any useful information. The others contain information that could be potentially useful.
#
# * A second important thing to take care of is the columns that contain values stored as objects that should be stored as numbers, like "price" and "odometer".
#
# We will convert them to floats

# %%
# Drop "ab_test" column
autos.drop("ab_test", axis=1, inplace=True)
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price vehicle_type  registration_year    gearbox  \
# 0  privat    Angebot  $5,000          bus               2004    manuell
# 1  privat    Angebot  $8,500    limousine               1997  automatik
# 2  privat    Angebot  $8,990    limousine               2009    manuell
# 3  privat    Angebot  $4,350   kleinwagen               2007  automatik
# 4  privat    Angebot  $1,350        kombi               2003    manuell
#
#    power_ps   model   odometer  registration_month fuel_type       brand  \
# ...

# %%
# Remove non_numeric characters from price and convert to numeric
autos["price"] = (autos["price"]
                .str.replace("$","")
                .str.replace(",","")
                .astype(float)
)
# Remove non_numeric characters from odometer and convert to numeric
autos["odometer"] = (autos["odometer"]
                    .str.replace("km","")
                    .str.replace(",","")
                    .astype(float)
)

autos.dtypes

# %%
autos.dtypes
# Out:
# date_crawled           object
# name                   object
# seller                 object
# offer_type             object
# price                 float64
# vehicle_type           object
# registration_year       int64
# gearbox                object
# power_ps                int64
# model                  object
# odometer_km           float64
# registration_month      int64
# fuel_type              object
# brand                  object
# unrepaired_damage      object
# ad_created             object
# num_photos              int64
# postal_code             int64
# last_seen              object
# dtype: object

# %%
# Rename "odometer" column
autos.rename({"odometer":"odometer_km"}, axis=1,inplace=True)

# %% [markdown]
# ## Exploring "price" and "odometer_km" columns further
#
# Now that we have converted the two columns "price" and "odometer" to numeric we can explore them further in the following cells and see if we find any unusual values(outliers)

# %%
autos["price"].unique().shape
autos["odometer_km"].unique().shape

autos["odometer_km"].value_counts()
# Out:
# 150000.0    32424
# 125000.0     5170
# 100000.0     2169
# 90000.0      1757
# 80000.0      1436
# 70000.0      1230
# 60000.0      1164
# 50000.0      1027
# 5000.0        967
# 40000.0       819
# 30000.0       789
# 20000.0       784
# 10000.0       264
# Name: odometer_km, dtype: int64

# %%
print(autos["price"].unique().shape)
print(autos["price"].describe())
autos["price"].value_counts().head(20)
# Out:
# (2357,)
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64
# 0.0       1421
# 500.0      781
# 1500.0     734
# 2500.0     643
# 1200.0     639
# 1000.0     639
# 600.0      531
# 800.0      498
# 3500.0     498
# 2000.0     460
# 999.0      434
# 750.0      433
# 900.0      420
# 650.0      419
# 850.0      410
# 700.0      395
# 4500.0     394
# 300.0      384
# 2200.0     382
# 950.0      379
# Name: price, dtype: int64

# %% [markdown]
# We notice that there are 1421 cars with a price of $0. These seem to be candidates for removal.
# We also see that the maximum price is one hundred million dollars, which seems a lot, let's look at the highest prices further.

# %%
autos["price"].value_counts().sort_index(ascending=False).head(20)
# Out:
# 99999999.0    1
# 27322222.0    1
# 12345678.0    3
# 11111111.0    2
# 10000000.0    1
# 3890000.0     1
# 1300000.0     1
# 1234566.0     1
# 999999.0      2
# 999990.0      1
# 350000.0      1
# 345000.0      1
# 299000.0      1
# 295000.0      1
# 265000.0      1
# 259000.0      1
# 250000.0      1
# 220000.0      1
# 198000.0      1
# 197000.0      1
# Name: price, dtype: int64

# %%
autos["price"].value_counts().sort_index(ascending=True).head(20)
# Out:
# 0.0     1421
# 1.0      156
# 2.0        3
# 3.0        1
# 5.0        2
# 8.0        1
# 9.0        1
# 10.0       7
# 11.0       2
# 12.0       3
# 13.0       2
# 14.0       1
# 15.0       2
# 17.0       3
# 18.0       1
# 20.0       4
# 25.0       5
# 29.0       1
# 30.0       7
# 35.0       1
# Name: price, dtype: int64

# %% [markdown]
# There are a number of listings with prices below \$30, including about 1,500 at \$0. There are also a small number of listings with very high values, including 14 at around or over $1 million.
#
# Given that eBay is an auction site, there could legitimately be items where the opening bid is \$1. We will keep the \$1 items, but remove anything above \$350,000, since it seems that prices increase steadily to that number and then jump up to less realistic numbers.

# %%
autos = autos[autos["price"].between(1,351000)]
autos["price"].describe()
# Out:
# count     48565.000000
# mean       5888.935591
# std        9059.854754
# min           1.000000
# 25%        1200.000000
# 50%        3000.000000
# 75%        7490.000000
# max      350000.000000
# Name: price, dtype: float64

# %% [markdown]
# ## Exploring the date columns

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48565 entries, 0 to 49999
# Data columns (total 19 columns):
# date_crawled          48565 non-null object
# name                  48565 non-null object
# seller                48565 non-null object
# offer_type            48565 non-null object
# price                 48565 non-null float64
# vehicle_type          43979 non-null object
# registration_year     48565 non-null int64
# gearbox               46222 non-null object
# power_ps              48565 non-null int64
# model                 46107 non-null object
# odometer_km           48565 non-null float64
# registration_month    48565 non-null int64
# fuel_type             44535 non-null object
# brand                 48565 non-null object
# unrepaired_damage     39464 non-null object
# ad_created            48565 non-null object
# num_photos            48565 non-null int64
# postal_code           48565 non-null int64
# last_seen             48565 non-null object
# ...

# %% [markdown]
# We notice that there are 5 date columns in the dataset. Of those, two are int type(registration_year, registration_month) which is convenient to work with.
#
# The other 3(date_crawled, ad_created, last_seen) are object type which means we will have to convert them.

# %%
autos[['date_crawled','ad_created','last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
# Select the first 10 characters in the column
autos["date_crawled"].str[:10]
# Out:
# 0        2016-03-26
# 1        2016-04-04
# 2        2016-03-26
# 3        2016-03-12
# 4        2016-04-01
# 5        2016-03-21
# 6        2016-03-20
# 7        2016-03-16
# 8        2016-03-22
# 9        2016-03-16
# 10       2016-03-15
# 11       2016-03-16
# 12       2016-03-31
# 13       2016-03-23
# 14       2016-03-23
# 15       2016-04-01
# 16       2016-03-16
# 17       2016-03-29
# 18       2016-03-26
# 19       2016-03-17
# 20       2016-03-05
# 21       2016-03-06
# 22       2016-03-28
# 23       2016-03-10
# 24       2016-04-03
# 25       2016-03-21
# 26       2016-04-03
# 28       2016-03-19
# 29       2016-04-02
# 30       2016-03-14
#             ...
# 49968    2016-04-01
# 49969    2016-03-17
# 49970    2016-03-21
# 49971    2016-03-29
# 49972    2016-03-26
# 49973    2016-03-27
# 49975    2016-03-27
# 49976    2016-03-19
# 49977    2016-03-31
# 49978    2016-04-04
# 49979    2016-03-20
# 49980    2016-03-12
# 49981    2016-03-15
# 49982    2016-03-29
# ...

# %%
#Select the first 10 characters of the column and create distribution
(autos["date_crawled"]
       .str[:10].value_counts(normalize=True, dropna=False)
       .sort_index()
        )
# Out:
# 2016-03-05    0.025327
# 2016-03-06    0.014043
# 2016-03-07    0.036014
# 2016-03-08    0.033296
# 2016-03-09    0.033090
# 2016-03-10    0.032184
# 2016-03-11    0.032575
# 2016-03-12    0.036920
# 2016-03-13    0.015670
# 2016-03-14    0.036549
# 2016-03-15    0.034284
# 2016-03-16    0.029610
# 2016-03-17    0.031628
# 2016-03-18    0.012911
# 2016-03-19    0.034778
# 2016-03-20    0.037887
# 2016-03-21    0.037373
# 2016-03-22    0.032987
# 2016-03-23    0.032225
# 2016-03-24    0.029342
# 2016-03-25    0.031607
# 2016-03-26    0.032204
# 2016-03-27    0.031092
# 2016-03-28    0.034860
# 2016-03-29    0.034099
# 2016-03-30    0.033687
# 2016-03-31    0.031834
# 2016-04-01    0.033687
# 2016-04-02    0.035478
# 2016-04-03    0.038608
# 2016-04-04    0.036487
# 2016-04-05    0.013096
# 2016-04-06    0.003171
# 2016-04-07    0.001400
# Name: date_crawled, dtype: float64

# %%
(autos["date_crawled"]
       .str[:10].value_counts(normalize=True, dropna=False)
       .sort_values()
        )
# Out:
# 2016-04-07    0.001400
# 2016-04-06    0.003171
# 2016-03-18    0.012911
# 2016-04-05    0.013096
# 2016-03-06    0.014043
# 2016-03-13    0.015670
# 2016-03-05    0.025327
# 2016-03-24    0.029342
# 2016-03-16    0.029610
# 2016-03-27    0.031092
# 2016-03-25    0.031607
# 2016-03-17    0.031628
# 2016-03-31    0.031834
# 2016-03-10    0.032184
# 2016-03-26    0.032204
# 2016-03-23    0.032225
# 2016-03-11    0.032575
# 2016-03-22    0.032987
# 2016-03-09    0.033090
# 2016-03-08    0.033296
# 2016-03-30    0.033687
# 2016-04-01    0.033687
# 2016-03-29    0.034099
# 2016-03-15    0.034284
# 2016-03-19    0.034778
# 2016-03-28    0.034860
# 2016-04-02    0.035478
# 2016-03-07    0.036014
# 2016-04-04    0.036487
# 2016-03-14    0.036549
# 2016-03-12    0.036920
# 2016-03-21    0.037373
# 2016-03-20    0.037887
# 2016-04-03    0.038608
# Name: date_crawled, dtype: float64

# %% [markdown]
# We see that the site was crawled daily over a period of one month approximately. The distribution of listings is roughly uniform

# %%
(autos["last_seen"]
        .str[:10]
        .value_counts(normalize=True, dropna=False)
        .sort_index()
        )
# Out:
# 2016-03-05    0.001071
# 2016-03-06    0.004324
# 2016-03-07    0.005395
# 2016-03-08    0.007413
# 2016-03-09    0.009595
# 2016-03-10    0.010666
# 2016-03-11    0.012375
# 2016-03-12    0.023783
# 2016-03-13    0.008895
# 2016-03-14    0.012602
# 2016-03-15    0.015876
# 2016-03-16    0.016452
# 2016-03-17    0.028086
# 2016-03-18    0.007351
# 2016-03-19    0.015834
# 2016-03-20    0.020653
# 2016-03-21    0.020632
# 2016-03-22    0.021373
# 2016-03-23    0.018532
# 2016-03-24    0.019767
# 2016-03-25    0.019211
# 2016-03-26    0.016802
# 2016-03-27    0.015649
# 2016-03-28    0.020859
# 2016-03-29    0.022341
# 2016-03-30    0.024771
# 2016-03-31    0.023783
# 2016-04-01    0.022794
# 2016-04-02    0.024915
# 2016-04-03    0.025203
# 2016-04-04    0.024483
# 2016-04-05    0.124761
# 2016-04-06    0.221806
# 2016-04-07    0.131947
# Name: last_seen, dtype: float64

# %% [markdown]
# For the "last_seen" column we see a disproportionate number of values in the last 3 days recorded.
# This spike probably does not signify an increase in sales but it is just because the crawling period is ending

# %%
print(autos["ad_created"].str[:10].unique().shape)
(autos["ad_created"]
        .str[:10]
        .value_counts(normalize=True, dropna=False)
        .sort_index()
        )
# Out:
# (76,)
# 2015-06-11    0.000021
# 2015-08-10    0.000021
# 2015-09-09    0.000021
# 2015-11-10    0.000021
# 2015-12-05    0.000021
# 2015-12-30    0.000021
# 2016-01-03    0.000021
# 2016-01-07    0.000021
# 2016-01-10    0.000041
# 2016-01-13    0.000021
# 2016-01-14    0.000021
# 2016-01-16    0.000021
# 2016-01-22    0.000021
# 2016-01-27    0.000062
# 2016-01-29    0.000021
# 2016-02-01    0.000021
# 2016-02-02    0.000041
# 2016-02-05    0.000041
# 2016-02-07    0.000021
# 2016-02-08    0.000021
# 2016-02-09    0.000021
# 2016-02-11    0.000021
# 2016-02-12    0.000041
# 2016-02-14    0.000041
# 2016-02-16    0.000021
# 2016-02-17    0.000021
# 2016-02-18    0.000041
# 2016-02-19    0.000062
# 2016-02-20    0.000041
# 2016-02-21    0.000062
#                 ...
# 2016-03-09    0.033151
# 2016-03-10    0.031895
# 2016-03-11    0.032904
# 2016-03-12    0.036755
# 2016-03-13    0.017008
# 2016-03-14    0.035190
# 2016-03-15    0.034016
# 2016-03-16    0.030125
# ...

# %% [markdown]
# We see that there is a large variety of unique ad_created dates

# %%
autos["registration_year"].describe()
# Out:
# count    48565.000000
# mean      2004.755421
# std         88.643887
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# Inspecting the registration_year column above, we see that there are some odd values there. For example the max year is 9999 and the min 1000. These of course make no sense so we will need to do some cleanup.

# %% [markdown]
# ## Cleaning incorrect registration year data
# Because a car can't be first registered before the listing was seen, any vehicle with a registration year above 2016 is definitely inaccurate. Determining the earliest valid year is more difficult. Realistically, it could be somewhere in the first few decades of the 1900s.
#
# One option is to remove the listings with these values. Let's determine what percentage of our data has invalid values in this column:

# %%
# Calculate percentage of invalid values in the column
(~autos["registration_year"].between(1900,2016)).sum() / autos.shape[0]
# Out:
# 0.038793369710697

# %% [markdown]
# Seeing that this is less than 4% of our data it is quite safe to remove those rows.

# %%
autos = autos[autos["registration_year"].between(1900,2016)]
autos["registration_year"].value_counts(normalize=True).head(10)
# Out:
# 2000    0.067608
# 2005    0.062895
# 1999    0.062060
# 2004    0.057904
# 2003    0.057818
# 2006    0.057197
# 2001    0.056468
# 2002    0.053255
# 1998    0.050620
# 2007    0.048778
# Name: registration_year, dtype: float64

# %% [markdown]
# ## Exploring Price by Brand

# %%
#Unique brands
print(autos["brand"].unique())
print(autos["brand"].unique().shape)
# Out:
# ['peugeot' 'bmw' 'volkswagen' 'smart' 'ford' 'chrysler' 'seat' 'renault'
#  'mercedes_benz' 'audi' 'sonstige_autos' 'opel' 'mazda' 'porsche' 'mini'
#  'toyota' 'dacia' 'nissan' 'jeep' 'saab' 'volvo' 'mitsubishi' 'jaguar'
#  'fiat' 'skoda' 'subaru' 'kia' 'citroen' 'chevrolet' 'hyundai' 'honda'
#  'daewoo' 'suzuki' 'trabant' 'land_rover' 'alfa_romeo' 'lada' 'rover'
#  'daihatsu' 'lancia']
# (40,)

# %%
autos["brand"].value_counts(normalize=True)
# Out:
# volkswagen        0.211264
# bmw               0.110045
# opel              0.107581
# mercedes_benz     0.096463
# audi              0.086566
# ford              0.069900
# renault           0.047150
# peugeot           0.029841
# fiat              0.025642
# seat              0.018273
# skoda             0.016409
# nissan            0.015274
# mazda             0.015188
# smart             0.014160
# citroen           0.014010
# toyota            0.012703
# hyundai           0.010025
# sonstige_autos    0.009811
# volvo             0.009147
# mini              0.008762
# mitsubishi        0.008226
# honda             0.007840
# kia               0.007069
# alfa_romeo        0.006641
# porsche           0.006127
# suzuki            0.005934
# chevrolet         0.005698
# chrysler          0.003513
# dacia             0.002635
# daihatsu          0.002506
# jeep              0.002271
# subaru            0.002142
# land_rover        0.002099
# saab              0.001649
# ...

# %%
brand_counts = autos["brand"].value_counts(normalize=True)
common_brands = brand_counts[brand_counts > .05].index
print(common_brands)
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %%
brand_mean_prices = {}

for brand in common_brands:
    brand_only = autos[autos["brand"] == brand]
    mean_price = brand_only["price"].mean()
    brand_mean_prices[brand] = int(mean_price)

brand_mean_prices
# Out:
# {'audi': 9336,
#  'bmw': 8332,
#  'ford': 3749,
#  'mercedes_benz': 8628,
#  'opel': 2975,
#  'volkswagen': 5402}

# %% [markdown]
# Of the top 5 brands, there is a distinct price gap:
#
# Audi, BMW and Mercedes Benz are more expensive
# Ford and Opel are less expensive
# Volkswagen is in between - this may explain its popularity, it may be a 'best of 'both worlds' option.

# %% [markdown]
# ## Exploring Mileage

# %%
bmp_series = pd.Series(brand_mean_prices)
pd.DataFrame(bmp_series, columns=["mean_price"])
# Out:
#                mean_price
# audi                 9336
# bmw                  8332
# ford                 3749
# mercedes_benz        8628
# opel                 2975
# volkswagen           5402

# %%
brand_mean_mileage = {}

for brand in common_brands:
    brand_only = autos[autos["brand"] == brand]
    mean_mileage = brand_only["odometer_km"].mean()
    brand_mean_mileage[brand] = int(mean_mileage)

mean_mileage = pd.Series(brand_mean_mileage).sort_values(ascending=False)
mean_prices = pd.Series(brand_mean_prices).sort_values(ascending=False)

# %%
brand_info = pd.DataFrame(mean_mileage,columns=['mean_mileage'])
brand_info
# Out:
#                mean_mileage
# bmw                  132572
# mercedes_benz        130788
# opel                 129310
# audi                 129157
# volkswagen           128707
# ford                 124266

# %%
brand_info["mean_price"] = mean_prices
brand_info
# Out:
#                mean_mileage  mean_price
# bmw                  132572        8332
# mercedes_benz        130788        8628
# opel                 129310        2975
# audi                 129157        9336
# volkswagen           128707        5402
# ford                 124266        3749

# %% [markdown]
# The range of car mileages does not vary as much as the prices do by brand, instead all falling within 10% for the top brands. There is a slight trend to the more expensive vehicles having higher mileage, with the less expensive vehicles having lower mileage.
